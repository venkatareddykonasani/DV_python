# %% [markdown]
# # Numbers

# %%
age=30
income=1250.567

# %%
print(type(age))
print(type(income))

# %%
print("Age - datatype", type(age))
print("Income - datatype", type(income))

# %% [markdown]
# # Strings

# %%
name="Sheldon"
print(name)

# %%
print(name[0])

# %%
print(name[1])

# %%
print(name[0:3])

# %%
print(name[3:6])

# %%
print(name[3:4])

# %%
message="Python 5 day course - Statinfer"
print(message)

# %%
print(message[0:4])

# %%
print(len(message))

# %%
print(message[24:31])

# %%
print(message[20:31])

# %%
First_name="Sheldon"
Last_name="Cooper"
Name= First_name + Last_name

# %%
print(Name)

# %%
Name1= First_name +" "+ Last_name
print(Name1)

# %%
print(Name*10)

# %% [markdown]
# ## LAB : Strings

# %%
text = " Hello World "

# %%
# index location of 'r'
text.find('r')
# Out:
# 9

# %%
text[9]
# Out:
# 'r'

# %%
# remove spaces before and after
text1 = text[1:len(text)-1]
text1
# alternative method
# text = text.strip()

# %%
# Extract 'ello'
text[1:5]

# %%
# access 'w' using it's index position
text[6]

# %%
# add '!' at the end
text + '!'

# %% [markdown]
# # Boolean

# %%
a=5>6

# %%
print(a)

# %%
print(type(a))

# %%
if a :
  print(10)
else:
  print(15)

# %% [markdown]
# # List

# %%
cust=["Sheldon","leonard", "penny"]
Age=[30, 31, 27]

# %%
print(cust)

# %%
print(Age)

# %%
print(cust[0])

# %%
print(Age[1])

# %% [markdown]
# ## Appending

# %%
cust_1=["Amy", "Raj"]

# %%
cust_1.sort()

# %%
Final_cust=cust + cust_1

# %%
print(Final_cust)

# %%
print(len(Final_cust))

# %%
Final_cust.append("Howard")

# %%
print(Final_cust)

# %% [markdown]
# ## remove

# %%
Final_cust.remove("penny")

# %%
print(Final_cust)

# %%
Age=[30, 31, 27, 30, 48]
Age.remove(30)
print("After removing 30 ==>", Age)

# %% [markdown]
# ## pop

# %%
sales=[300, 350, 200, 250, 300]
sales.pop(0)

# %%
print("sales after pop ==>", sales)

# %%
sales.pop(0)
print("sales after second pop ==>", sales)

# %% [markdown]
# ## Sorting

# %%
Loans=[3, 0, 2, 6, 20]
Loans.sort()

# %%
print(Loans)

# %%
Loans.sort(reverse=True)

# %%
print(Loans)

# %% [markdown]
# ## Negative Index

# %%
sales=[300, 350, 200, 250, 400]
print(sales[-1])

# %%
print(sales[-1],sales[-2], sales[-3], sales[-4], sales[-5])

# %% [markdown]
# ## Slicing

# %%
Age=[15, 44, 38, 19, 36, 25]
print(Age[2:5])
# Out:
# [38, 19, 36]

# %%
print(Age[2:10])
# Out:
# [38, 19, 36, 25]

# %%
print(Age[2:])

# %%
print(Age[:4])

# %%
print(Age[-4:-2])

# %%
print(Age[:-4])
# Out:
# [15, 44]

# %%
print(Age[-4:])

# %% [markdown]
# ## Lab - List Operations

# %%
#Create names list
names = ['Stan', 'Kyle', 'Cartman', 'Kenny']

# %%
# Change kenny to butters
names[-1] = 'Butters'
names
# Out:
# ['Stan', 'Kyle', 'Cartman', 'Butters']

# %%
# Insert clyde after Stan
names.insert(2,'Clyde')
names
# Out:
# ['Stan', 'Kyle', 'Clyde', 'Cartman', 'Butters']

# %%
b = names.pop(-1)
print('the popped item is: ', b)
print('list after popping: ',names)
# Out:
# the popped item is:  Butters
# list after popping:  ['Stan', 'Kyle', 'Clyde', 'Cartman']

# %%
names[-3:]

# %%
#Reversing a list
Age=[15, 44, 38, 19, 36, 25]
Age.reverse()
print(Age)

# %%
# Get min and max of list
print("max value in the list is : ", max(Age))
print("Min value in the list is : ", min(Age))

# %%
# count of elements inside a list
len(Age)

# %%
# Access value of particular value inside a list
cust=["Sheldon","leonard", "penny"]
cust.index("leonard")
# Out:
# 1

# %%
# Access value of particular value inside a list
cust=["Sheldon","leonard", "penny","leonard"]
cust.index("leonard")
# Out:
# 1

# %% [markdown]
# # Tuples

# %% [markdown]
# ## Create and Access

# %%
custd_id=("c00194", "c00195", "c00198")

# %%
type(custd_id)

# %%
rank=(1, 46, "NA", 5, 8)

# %%
type(rank[1])

# %%
print(type(rank[1]),type(rank[2]))

# %% [markdown]
# ## Packing

# %%
region= "E", "W", "N", "S"

# %%
type(region)

# %%
r1, r2, r3, r4= region

# %%
print(r1, r4)

# %%
print(type(r1))

# %% [markdown]
# ## Tuple vs List

# %%
custd_id_t=("c00194", "c00195", "c00198")
custd_id_l=["c00194", "c00195", "c00198"]

# %%
custd_id_l[1]="c00176"

# %%
custd_id_t[1]="c00176"

# %%
from sys import getsizeof

custd_id_t=("c00194", "c00195", "c00198")
custd_id_l=["c00194", "c00195", "c00198"]
print("tupple size ", getsizeof(custd_id_t))
print("list size ", getsizeof(custd_id_l))

# %%
from timeit import timeit
timeit("list(['c00194', 'c00195', 'c00198'])", number=10000000)

# %%
timeit("tuple(('c00194', 'c00195', 'c00198'))", number=10000000)

# %% [markdown]
# ## Tuple with single element

# %%
country=("USA")

# %%
type(country)

# %%
country1=("USA",)

# %%
type(country1)

# %% [markdown]
# ## LAB : Tuple Operations

# %%
some_tuple = (2,5,4,6,names)
some_tuple
# Out:
# (2, 5, 4, 6, ['Stan', 'Kyle', 'Clyde', 'Cartman'])

# %%
some_tuple[4][0]
# Out:
# 'Stan'

# %%
some_tuple[4][-1] = "Shaktiman"
some_tuple
# Out:
# (2, 5, 4, 6, ['Stan', 'Kyle', 'Clyde', 'Shaktiman'])

# %%
names
# Out:
# ['Stan', 'Kyle', 'Clyde', 'Shaktiman']

# %% [markdown]
# # Dictionaries

# %%
city={0:"L.A", 9:"P.A", 7:"FL"}

# %%
type(city)

# %%
print(city)

# %%
city[1]

# %%
city[0]

# %%
city[9]

# %%
city[7]

# %%
city.keys()

# %%
city.values()

# %%
cust_profile={"C001":"David", "C002":"Bill", "C003":"Jim"}

# %%
cust_profile[0]

# %%
cust_profile[C001]

# %%
cust_profile["C001"]

# %%
cust_profile["C002"]

# %%
#Updating values
cust_profile["C002"]="Tom"

# %%
print(cust_profile)

# %%
#Updating Keys
#C001 ---> C009

#Delete + Add

del(cust_profile["C001"])

# %%
print(cust_profile)

# %%
cust_profile["C009"]="David"

# %%
print(cust_profile)

# %% [markdown]
# ## Iterating in Dictionaries

# %%
Employee = {"Name": "Tom", "Emp_id": 198876, "Age": 29, "salary":25000,"Company":"FB"}
for x in Employee:
    print(x)

# %%
for x in Employee.values():
    print(x)

# %%
for x in Employee.keys():
    print(x)

# %%
for x in Employee.keys():
    print(x,Employee[x])

# %%
for x in Employee.items():
    print(x)

# %% [markdown]
# ## LAB: Dictionary Operations

# %%
# Create a dictionary
name_age ={'Stan':8, 'Kyle':8, 'Cartman':10}
name_age

# %%
name_age['Cartman']

# %%
# add a new key pair:
name_age['Kenny'] = 9
name_age

# %%
# Updating a dictionary with dictionary(multiple value update)
name_age.update({'Cartman':11, 'Token':10})
name_age

# %%
519+98

# %%
78*91

# %%
459-67
